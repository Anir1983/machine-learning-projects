# %% [markdown]
# <a href="https://colab.research.google.com/github/Anir1983/machine-learning-projects/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Employees.csv")

# %%
# dispaly the top five rows
print(df.head())
# Out:
#    EmpID   Name     City  Age   Salary Department
# 0    101  Alice   London   32  50000.0         HR
# 1    102    Bob    Paris   31  60000.0    Finance
# 2    103  Chris  NewYork   35  40000.0        DBA
# 3    104  David   London   37      NaN         IT
# 4    105  Emily    Paris   33  55000.0         HR

# %%
#shape
print(df.shape)
# Out:
# (8, 6)
